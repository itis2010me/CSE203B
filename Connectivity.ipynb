# %%
import numpy as np
import csv


datas = []

counties = [
    'Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa', 'Contra Costa',
    'Del Norte', 'El Dorado', 'Fresno', 'Glenn', 'Humboldt', 'Imperial', 'Inyo',
    'Kern', 'Kings', 'Lake', 'Lassen', 'Los Angeles', 'Madera', 'Marin', 'Mariposa',
    'Mendocino', 'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange',
    'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito', 'San Bernardino',
    'San Diego', 'San Francisco', 'San Joaquin', 'San Luis Obispo', 'San Mateo',
    'Santa Barbara', 'Santa Clara', 'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou',
    'Solano', 'Sonoma', 'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare',
    'Tuolumne', 'Ventura', 'Yolo', 'Yuba'
]

datas.append(["Alameda, CA",
              "Alameda, CA",
              "Contra Costa, CA",
              "San Francisco, CA",
              "San Joaquin, CA",
              "San Mateo, CA",
              "Santa Clara, CA",
              "Stanislaus, CA"]
             )
datas.append([
    "Alpine, CA","Alpine, CA",
    "Amador, CA",
    "Calaveras, CA",
    "El Dorado, CA",
    "Mono, CA",
    "Tuolumne, CA",
    "Douglas, NV"
]
)

datas.append([
    "Amador, CA",
    "Alpine, CA",
    "Amador, CA",
    "Calaveras, CA",
    "El Dorado, CA",
    "Sacramento, CA",
    "San Joaquin, CA"
]
)

datas.append([
    "Butte, CA","Butte, CA",
    "Colusa, CA",
    "Glenn, CA",
    "Plumas, CA",
    "Sutter, CA",
    "Tehama, CA",
    "Yuba, CA",
]
)

datas.append([
    "Calaveras, CA"	,	"Alpine, CA"	,
    "Amador, CA"	,
    "Calaveras, CA"	,
    "San Joaquin, CA"	,
    "Stanislaus, CA"	,
    "Tuolumne, CA"	,
]
)

datas.append([
    "Colusa, CA"	,	"Butte, CA"	,
    "Colusa, CA"	,
    "Glenn, CA",
    "Lake, CA",
    "Sutter, CA",
    "Yolo, CA",
]
)

datas.append([
    "Contra Costa, CA"	,	"Alameda, CA"	,
    "Contra Costa, CA"	,
    "Marin, CA"	,
    "Sacramento, CA"	,
    "San Francisco, CA"	,
    "San Joaquin, CA"	,
    "Solano, CA"	,
    "Sonoma, CA"	,
]
)

datas.append([
    "Del Norte, CA"	,	"Del Norte, CA"	,
    "Humboldt, CA"	,
    "Siskiyou, CA"	,
    "Curry, OR"	,
    "Josephine, OR"	,
]
)

datas.append([
    "El Dorado, CA"	,	"Alpine, CA"	,
    "Amador, CA"	,
    "El Dorado, CA"	,
    "Placer, CA"	,
    "Sacramento, CA"	,
    "Douglas, NV"	,
]
)

datas.append([
    "Fresno, CA"	,	"Fresno, CA"	,
    "Inyo, CA"	,
    "Kings, CA"	,
    "Madera, CA"	,
    "Merced, CA"	,
    "Mono, CA"	,
    "Monterey, CA"	,
    "San Benito, CA"	,
    "Tulare, CA"	,
]
)

datas.append([
    "Glenn, CA"	,	"Butte, CA"	,
    "Colusa, CA"	,
    "Glenn, CA"	,
    "Lake, CA"	,
    "Mendocino, CA"	,
    "Tehama, CA"	,
]
)

datas.append([
    "Humboldt, CA"	,	"Del Norte, CA"	,
    "Humboldt, CA"	,
    "Mendocino, CA"	,
    "Siskiyou, CA"	,
    "Trinity, CA"	,
]
)

datas.append([
    "Imperial, CA"	,	"La Paz, AZ"	,
    "Yuma, AZ"	,
    "Imperial, CA"	,
    "Riverside, CA"	,
    "San Diego, CA"	,
]
)

datas.append([
    "Inyo, CA"	,	"Fresno, CA"	,
    "Inyo, CA"	,
    "Kern, CA"	,
    "Mono, CA"	,
    "San Bernardino, CA"	,
    "Tulare, CA"	,
    "Clark, NV"	,
    "Esmeralda, NV"	,
    "Nye, NV"	,
]
)

datas.append([
    "Kern, CA"	,	"Inyo, CA"	,
    "Kern, CA"	,
    "Kings, CA"	,
    "Los Angeles, CA"	,
    "San Bernardino, CA"	,
    "San Luis Obispo, CA"	,
    "Santa Barbara, CA"	,
    "Tulare, CA"	,
    "Ventura, CA"	,
]
)


datas.append([
    "Kings, CA"	,	"Fresno, CA"	,
    "Kern, CA"	,
    "Kings, CA"	,
    "Monterey, CA"	,
    "San Luis Obispo, CA"	,
    "Tulare, CA"	,
]
)

datas.append([
    "Lake, CA"	,	"Colusa, CA"	,
    "Glenn, CA"	,
    "Lake, CA"	,
    "Mendocino, CA"	,
    "Napa, CA"	,
    "Sonoma, CA"	,
    "Yolo, CA"	,
]
)

datas.append([
    "Lassen, CA"	,	"Lassen, CA"	,
    "Modoc, CA"	,
    "Plumas, CA"	,
    "Shasta, CA"	,
    "Sierra, CA"	,
    "Washoe, NV"	,
]
)

datas.append([
    "Los Angeles, CA"	,	"Kern, CA"	,
    "Los Angeles, CA"	,
    "Orange, CA"	,
    "San Bernardino, CA"	,
    "Ventura, CA"	,
]
)

datas.append([
    "Madera, CA"	,	"Fresno, CA"	,
    "Madera, CA"	,
    "Mariposa, CA"	,
    "Merced, CA"	,
    "Mono, CA"	,
    "Tuolumne, CA"	,
]
)

datas.append([
    "Marin, CA"	,	"Contra Costa, CA"	,
    "Marin, CA"	,
    "San Francisco, CA"	,
    "Solano, CA"	,
    "Sonoma, CA"	,
]
)

datas.append([
    "Mariposa, CA"	,	"Madera, CA"	,
    "Mariposa, CA"	,
    "Merced, CA"	,
    "Stanislaus, CA"	,
    "Tuolumne, CA"	,
]
)

datas.append([
    "Mendocino, CA"	,	"Glenn, CA"	,
    "Humboldt, CA"	,
    "Lake, CA"	,
    "Mendocino, CA"	,
    "Sonoma, CA"	,
    "Tehama, CA"	,
    "Trinity, CA"	,
]
)

datas.append([
    "Merced, CA"	,	"Fresno, CA"	,
    "Madera, CA"	,
    "Mariposa, CA"	,
    "Merced, CA"	,
    "San Benito, CA"	,
    "Santa Clara, CA"	,
    "Stanislaus, CA"	,
]
)

datas.append([
    "Modoc, CA"	,	"Lassen, CA"	,
    "Modoc, CA"	,
    "Shasta, CA"	,
    "Siskiyou, CA"	,
    "Washoe, NV"	,
    "Klamath, OR"	,
    "Lake, OR"	,
]
)

datas.append([
    "Mono, CA"	,	"Alpine, CA"	,
    "Fresno, CA"	,
    "Inyo, CA"	,
    "Madera, CA"	,
    "Mono, CA"	,
    "Tuolumne, CA"	,
    "Douglas, NV"	,
    "Esmeralda, NV"	,
    "Lyon, NV"	,
    "Mineral, NV"	,
]
)

datas.append([
    "Monterey, CA"	,	"Fresno, CA"	,
    "Kings, CA"	,
    "Monterey, CA"	,
    "San Benito, CA"	,
    "San Luis Obispo, CA"	,
    "Santa Cruz, CA"	,
]
)

datas.append([
    "Napa, CA"	,	"Lake, CA"	,
    "Napa, CA"	,
    "Solano, CA"	,
    "Sonoma, CA"	,
    "Yolo, CA"	,
]
)


datas.append([
    "Nevada, CA"	,	"Nevada, CA"	,
    "Placer, CA"	,
    "Sierra, CA"	,
    "Yuba, CA"	,
    "Washoe, NV"	,
]
)

datas.append([
    "Orange, CA"	,	"Los Angeles, CA"	,
    "Orange, CA"	,
    "Riverside, CA"	,
    "San Bernardino, CA"	,
    "San Diego, CA"	,
]
)

datas.append([
    "Placer, CA"	,	"El Dorado, CA"	,
    "Nevada, CA"	,
    "Placer, CA"	,
    "Sacramento, CA"	,
    "Sutter, CA"	,
    "Yuba, CA"	,
    "Douglas, NV"	,
    "Washoe, NV"	,
    "Carson City, NV"	,
]
)

datas.append([
    "Plumas, CA"	,	"Butte, CA"	,
    "Lassen, CA"	,
    "Plumas, CA"	,
    "Shasta, CA"	,
    "Sierra, CA"	,
    "Tehama, CA"	,
    "Yuba, CA"	,
]
)

datas.append([
    "Riverside, CA"	,	"La Paz, AZ"	,
    "Imperial, CA"	,
    "Orange, CA"	,
    "Riverside, CA"	,
    "San Bernardino, CA"	,
    "San Diego, CA"	,
]
)

datas.append([
    "Sacramento, CA"	,	"Amador, CA"	,
    "Contra Costa, CA"	,
    "El Dorado, CA"	,
    "Placer, CA"	,
    "Sacramento, CA"	,
    "San Joaquin, CA"	,
    "Solano, CA"	,
    "Sutter, CA"	,
    "Yolo, CA"	,
]
)

datas.append([
    "San Benito, CA"	,	"Fresno, CA"	,
    "Merced, CA"	,
    "Monterey, CA"	,
    "San Benito, CA"	,
    "Santa Clara, CA"	,
    "Santa Cruz, CA"	,
]
)

datas.append([
    "San Bernardino, CA"	,	"La Paz, AZ"	,
    "Mohave, AZ"	,
    "Inyo, CA"	,
    "Kern, CA"	,
    "Los Angeles, CA"	,
    "Orange, CA"	,
    "Riverside, CA"	,
    "San Bernardino, CA"	,
    "Clark, NV"	,
]
)

datas.append([
    "San Diego, CA"	,	"Imperial, CA"	,
    "Orange, CA"	,
    "Riverside, CA"	,
    "San Diego, CA"	,
]
)

datas.append([
    "San Francisco, CA"	,	"Alameda, CA"	,
    "Contra Costa, CA"	,
    "Marin, CA"	,
    "San Francisco, CA"	,
    "San Mateo, CA"	,
]
)

datas.append([
    "San Joaquin, CA"	,	"Alameda, CA"	,
    "Amador, CA"	,
    "Calaveras, CA"	,
    "Contra Costa, CA"	,
    "Sacramento, CA"	,
    "San Joaquin, CA"	,
    "Stanislaus, CA"	,
]
)

datas.append([
    "San Luis Obispo, CA"	,	"Kern, CA"	,
    "Kings, CA"	,
    "Monterey, CA"	,
    "San Luis Obispo, CA"	,
    "Santa Barbara, CA"	,
]
)

datas.append([
    "San Mateo, CA"	,	"Alameda, CA"	,
    "San Francisco, CA"	,
    "San Mateo, CA"	,
    "Santa Clara, CA"	,
    "Santa Cruz, CA"	,
]
)


datas.append([
    "Santa Barbara, CA"	,	"Kern, CA"	,
    "San Luis Obispo, CA"	,
    "Santa Barbara, CA"	,
    "Ventura, CA"	,
]
)

datas.append([
    "Santa Clara, CA"	,	"Alameda, CA"	,
    "Merced, CA"	,
    "San Benito, CA"	,
    "San Mateo, CA"	,
    "Santa Clara, CA"	,
    "Santa Cruz, CA"	,
    "Stanislaus, CA"	,
]
)

datas.append([
    "Santa Cruz, CA"	,	"Monterey, CA"	,
    "San Benito, CA"	,
    "San Mateo, CA"	,
    "Santa Clara, CA"	,
    "Santa Cruz, CA"	,
]
)

datas.append([
    "Shasta, CA"	,	"Lassen, CA"	,
    "Modoc, CA"	,
    "Plumas, CA"	,
    "Shasta, CA"	,
    "Siskiyou, CA"	,
    "Tehama, CA"	,
    "Trinity, CA"	,
]
)

datas.append([
    "Sierra, CA"	,	"Lassen, CA"	,
    "Nevada, CA"	,
    "Plumas, CA"	,
    "Sierra, CA"	,
    "Yuba, CA"	,
    "Washoe, NV"	,
]
)

datas.append([
    "Siskiyou, CA"	,	"Del Norte, CA"	,
    "Humboldt, CA"	,
    "Modoc, CA"	,
    "Shasta, CA"	,
    "Siskiyou, CA"	,
    "Trinity, CA"	,
    "Jackson, OR"	,
    "Josephine, OR"	,
    "Klamath, OR"	,
]
)

datas.append([
    "Solano, CA"	,	"Contra Costa, CA"	,
    "Marin, CA"	,
    "Napa, CA"	,
    "Sacramento, CA"	,
    "Solano, CA"	,
    "Sonoma, CA"	,
    "Yolo, CA"	,
]
)

datas.append([
    "Sonoma, CA"	,	"Contra Costa, CA"	,
    "Lake, CA"	,
    "Marin, CA"	,
    "Mendocino, CA"	,
    "Napa, CA"	,
    "Solano, CA"	,
    "Sonoma, CA"	,
])

datas.append([
    "Stanislaus, CA"	,	"Alameda, CA"	,
    "Calaveras, CA"	,
    "Mariposa, CA"	,
    "Merced, CA"	,
    "San Joaquin, CA"	,
    "Santa Clara, CA"	,
    "Stanislaus, CA"	,
    "Tuolumne, CA"	,
])
datas.append([
    "Sutter, CA"	,	"Butte, CA"	,
    "Colusa, CA"	,
    "Placer, CA"	,
    "Sacramento, CA"	,
    "Sutter, CA"	,
    "Yolo, CA"	,
    "Yuba, CA"	,
])

datas.append([
    "Tehama, CA"	,	"Butte, CA"	,
    "Glenn, CA"	,
    "Mendocino, CA"	,
    "Plumas, CA"	,
    "Shasta, CA"	,
    "Tehama, CA"	,
    "Trinity, CA"	,
])
datas.append([
    "Trinity, CA"	,	"Humboldt, CA"	,
    "Mendocino, CA"	,
    "Shasta, CA"	,
    "Siskiyou, CA"	,
    "Tehama, CA"	,
    "Trinity, CA"	,
])

datas.append([
    "Tulare, CA"	,	"Fresno, CA"	,
    "Inyo, CA"	,
    "Kern, CA"	,
    "Kings, CA"	,
    "Tulare, CA"	,
])

datas.append([
    "Tuolumne, CA"	,	"Alpine, CA"	,
    "Calaveras, CA"	,
    "Madera, CA"	,
    "Mariposa, CA"	,
    "Mono, CA"	,
    "Stanislaus, CA"	,
    "Tuolumne, CA"	,
])

datas.append([
    "Ventura, CA"	,	"Kern, CA"	,
    "Los Angeles, CA"	,
    "Santa Barbara, CA"	,
    "Ventura, CA"	,
])
datas.append([
    "Yolo, CA"	,	"Colusa, CA"	,
    "Lake, CA"	,
    "Napa, CA"	,
    "Sacramento, CA"	,
    "Solano, CA"	,
    "Sutter, CA"	,
    "Yolo, CA"	,
])

datas.append([
    "Yuba, CA"	,	"Butte, CA"	,
    "Nevada, CA"	,
    "Placer, CA"	,
    "Plumas, CA"	,
    "Sierra, CA"	,
    "Sutter, CA"	,
    "Yuba, CA"	,
])


adjacency_dict = {}
for i in range(58):
    data = datas[i]
    adj_list = []
    adjacency_dict[data[0].split(",")[0]] = adj_list
    for row in data:
        temp = row.split(",")

        if temp[1] == " CA":
            if temp[0] != data[0].split(",")[0]:
                adj_list.append(temp[0])


print(len(adjacency_dict.keys()))
print(adjacency_dict["Orange"])
# Out:
# 58
# ['Los Angeles', 'Riverside', 'San Bernardino', 'San Diego']

# %%
# create the 58x58 matrix
county_matrix = np.zeros((58, 58))

# iterate over the dictionary to populate the matrix
for i, county in enumerate(counties):
    for neighbor in adjacency_dict[county]:
        j = counties.index(neighbor)
        county_matrix[i][j] = 1
        # print("County: ",county, " Neighbor: ",neighbor)

count = 0
for i in range(len(county_matrix)):
    for j in range(len(county_matrix[0])):
        if county_matrix[i][j] != 0:
            count += 1

# %%
import pandas as pd
# filename = 'connectivity.csv'
header = counties
data = county_matrix

data = pd.DataFrame(data, columns=header)
data.to_csv('connectivity.csv', index=False)

# %%
# Create a dictionary of counties' area
county_areas = {
    'Alameda': [252000],
    'Alpine': [302140.0],
    'Amador': [279700],
    'Butte': [500800],
    'Calaveras': [524400],
    'Colusa': [241500],
    'Contra Costa': [192200],
    'Del Norte': [172500],
    'El Dorado': [404900],
    'Fresno': [774800],
    'Glenn': [290100],
    'Humboldt': [1542800],
    'Imperial': [1800],
    'Inyo': [322300],
    'Kern': [345225.0],
    'Kings': [149000],
    'Lake': [355600],
    'Lassen': [592200],
    'Los Angeles': [163906.25],
    'Madera': [368100],
    'Marin': [268275.0],
    'Mariposa': [426900],
    'Mendocino': [1838600],
    'Merced': [393900],
    'Modoc': [371500],
    'Mono': [2500],
    'Monterey': [1250600],
    'Napa': [360400],
    'Nevada': [298300],
    'Orange': [529051.5625],
    'Placer': [272600],
    'Plumas': [96600],
    'Riverside': [554600],
    'Sacramento': [113500],
    'San Benito': [729000],
    'San Bernardino': [310400],
    'San Diego': [1087300],
    'San Francisco': [222218.75],
    'San Joaquin': [145200],
    'San Luis Obispo': [1406300],
    'San Mateo': [176400],
    'Santa Barbara': [583841.6666666666],
    'Santa Clara': [557700],
    'Santa Cruz': [228600],
    'Shasta': [1145000],
    'Sierra': [291700.0],
    'Siskiyou': [1032500],
    'Solano': [86900],
    'Sonoma': [794000],
    'Stanislaus': [425500],
    'Sutter': [247883.33333333334],
    'Tehama': [1148900],
    'Trinity': [259200],
    'Tulare': [573800],
    'Tuolumne': [299200],
    'Ventura': [364324.3055555555],
    'Yolo': [179200],
    'Yuba': [179700]
}

# Alpine
# Kern
# Los Angeles
# Marin
# Orange
# San Francisco
# Santa Barbara
# Sierra
# Sutter
# Ventura

# for key in county_areas.keys():
#     if county_areas[key][0] == 0:
#         adj_areas = []
#         for neighbor in adjacency_dict[key]:
#             adj_areas.append(county_areas[neighbor][0])
#         county_areas[key][0] = np.mean(adj_areas)

emergency_fire_suppression_budget = [300, 900, 838, 413]
cost_per_acre = 100
total_budget = np.mean(emergency_fire_suppression_budget)
county_cost_matrix = {county: {county_areas[county][0] * cost_per_acre} for county in county_areas.keys()}

# %%
print(county_cost_matrix)
# Out:
# {'Alameda': {25200000}, 'Alpine': {30214000.0}, 'Amador': {27970000}, 'Butte': {50080000}, 'Calaveras': {52440000}, 'Colusa': {24150000}, 'Contra Costa': {19220000}, 'Del Norte': {17250000}, 'El Dorado': {40490000}, 'Fresno': {77480000}, 'Glenn': {29010000}, 'Humboldt': {154280000}, 'Imperial': {180000}, 'Inyo': {32230000}, 'Kern': {34522500.0}, 'Kings': {14900000}, 'Lake': {35560000}, 'Lassen': {59220000}, 'Los Angeles': {16390625.0}, 'Madera': {36810000}, 'Marin': {26827500.0}, 'Mariposa': {42690000}, 'Mendocino': {183860000}, 'Merced': {39390000}, 'Modoc': {37150000}, 'Mono': {250000}, 'Monterey': {125060000}, 'Napa': {36040000}, 'Nevada': {29830000}, 'Orange': {52905156.25}, 'Placer': {27260000}, 'Plumas': {9660000}, 'Riverside': {55460000}, 'Sacramento': {11350000}, 'San Benito': {72900000}, 'San Bernardino': {31040000}, 'San Diego': {108730000}, 'San Francisco': {22221875.0}, 'San Joaquin': {14520000}, 'San Luis Obispo': {140630000}, 'San Mateo': {17640000}, 'Santa Barbara': {5
# ...

# %%
# Create a dictionary of counties' humidity
county_humidity = {
    'Alameda': [0.7771],
    'Alpine': [0.8014],
    'Amador': [0.8460],
    'Butte': [0.8175],
    'Calaveras': [0.8353],
    'Colusa': [0.8302],
    'Contra Costa': [0.7533],
    'Del Norte': [0.8394],
    'El Dorado': [0.8360],
    'Fresno': [0.7893],
    'Glenn': [0.8411],
    'Humboldt': [0.8615],
    'Imperial': [0.8255],
    'Inyo': [0.7661],
    'Kern': [0.7693],
    'Kings': [0.8034],
    'Lake': [0.8281],
    'Lassen': [0.8052],
    'Los Angeles': [0.7923],
    'Madera': [0.7881],
    'Marin': [0.8541],
    'Mariposa': [0.7984],
    'Mendocino': [0.8896],
    'Merced': [0.7948],
    'Modoc': [0.7942],
    'Mono': [0.7652],
    'Monterey': [0.8579],
    'Napa': [0.8229],
    'Nevada': [0.8011],
    'Orange': [0.7996],
    'Placer': [0.8151],
    'Plumas': [0.7620],
    'Riverside': [0.8244],
    'Sacramento': [0.8029],
    'San Benito': [0.8085],
    'San Bernardino': [0.7781],
    'San Diego': [0.8322],
    'San Francisco': [0.8741],
    'San Joaquin': [0.7782],
    'San Luis Obispo': [0.8341],
    'San Mateo': [0.8341],
    'Santa Barbara': [0.7803],
    'Santa Clara': [0.8151],
    'Santa Cruz': [0.8624],
    'Shasta': [0.7981],
    'Sierra': [0.7861],
    'Siskiyou': [0.8215],
    'Solano': [0.7498],
    'Sonoma': [0.8421],
    'Stanislaus': [0.7991],
    'Sutter': [0.8151],
    'Tehama': [0.8208],
    'Trinity': [0.8016],
    'Tulare': [0.7611],
    'Tuolumne': [0.7975],
    'Ventura': [0.8147],
    'Yolo': [0.8135],
    'Yuba': [0.8116]
}

# norm_humidity = np.linalg.norm(list(county_humidity.values()))

# def normalize(v, norm):
#     return v / norm

# county_humidity_normalized = {county: {normalize(county_humidity[county][0], norm_humidity)} for county in county_humidity.keys()}
# print(county_humidity_normalized)

# %%
# CAL FIRE projection on the fire probabilities of the CA counties.
# ranging (0.1 - 2)

fire_proba = {'Alameda': 2,
 'Alpine': 1.5,
 'Amador': 1.5,
 'Butte': 2,
 'Calaveras': 2,
 'Colusa': 2,
 'Contra Costa': 0.1,
 'Del Norte': 2,
 'El Dorado': 2,
 'Fresno': 1,
 'Glenn': 2,
 'Humboldt': 2,
 'Imperial': 0.1,
 'Inyo': 0.1,
 'Kern': 2,
 'Kings': 0.5,
 'Lake': 1,
 'Lassen': 2,
 'Los Angeles': 1.5,
 'Madera': 2,
 'Marin': 2,
 'Mariposa': 2,
 'Mendocino': 2,
 'Merced': 2,
 'Modoc': 1,
 'Mono': 1.5,
 'Monterey': 2,
 'Napa': 2,
 'Nevada': 2,
 'Orange': 2,
 'Placer': 2,
 'Plumas': 1.5,
 'Riverside': 0.1,
 'Sacramento': 2,
 'San Benito': 2,
 'San Bernardino': 0.1,
 'San Diego': 2,
 'San Francisco': 0.2,
 'San Joaquin': 1,
 'San Luis Obispo': 2,
 'San Mateo': 0.2,
 'Santa Barbara': 2,
 'Santa Clara': 2,
 'Santa Cruz': 2,
 'Shasta': 2,
 'Sierra': 1.5,
 'Siskiyou': 2,
 'Solano': 2,
 'Sonoma': 2,
 'Stanislaus': 2,
 'Sutter': 0.5,
 'Tehama': 2,
 'Trinity': 2,
 'Tulare': 0.1,
 'Tuolumne': 1.5,
 'Ventura': 0.1,
 'Yolo': 1.5,
 'Yuba': 1.5}

# %%
# vectorize all data

# min-max normalization
def minmax(v):
    return (v - v.min())/(v.max() - v.min())


# humandity
humidity_v = np.zeros((58,1))
i = 0
for c in counties:
    humidity_v[i][0] = county_humidity[c][0]
    i += 1

humidity_v = 1 - minmax(humidity_v)


# fire probability
fire_v = np.zeros((58,1))
i = 0
for c in counties:
    fire_v[i][0] = fire_proba[c]
    i += 1

fire_v = minmax(fire_v)

# %%
C = np.zeros((58,58))

for i in range(58):
    for j in range(58):
        if county_matrix[i][j] == 1:
            C[i][j] = humidity_v[j]*0.5 + fire_v[j]*0.5

# %%
M_values = np.array([11335, 79621043, 386100, 86251, 347503, 378426, 21322, 331386, 397229208, 192405, 771357, 254222, 2053372, 103400, 333465, 149249, 1389704, 445601, 511873, 200650, 116180, 18670, 739052, 16470, 50200, 16051980, 112020, 10101, 720900, 1711129, 61636121, 2003500, 2598441, 3200, 368564, 2225900, 1508303, 37959, 22099, 9606, 3000, 92286, 12750, 39850, 31358970, 1293350, 408550, 119700, 443400, 114501, 10705233, 1263355, 920000, 98750, 142405, 312541, 124000, 2003400])
M = np.diag(M_values)
np.shape(M)

S_values = np.zeros((58,))
for i in range(58):
    S_values[i] = np.sum(M @ C[i])

S = np.diag(S_values)

# %%
# scale M and S down by 10^3

M = M / 1000
S = S / 1000

# %%
import csv
import pandas as pd

header = counties
data = S

data = pd.DataFrame(data, columns=header)
data.to_csv('S_matrix.csv', index=False)

# %%
# California county coordinates
county_longitude_ranges = {
    'Alameda': [122.23, 121.28],
    'Alpine': [120.05, 119.32],
    'Amador': [121.02, 120.04],
    'Butte': [122.05, 121.04],
    'Calaveras': [121.00, 120.01],
    'Colusa': [122.47, 121.47],
    'Contra Costa': [122.26, 121.32],
    'Del Norte': [124.15, 123.31],
    'El Dorado': [121.09, 119.52],
    'Fresno': [120.56, 118.21],
    'Glenn': [122.56, 121.51],
    'Humboldt': [124.25, 123.24],
    'Imperial': [116.07, 114.27],
    'Inyo': [118.47, 115.38],
    'Kern': [120.12, 117.37],
    'Kings': [120.19, 119.28],
    'Lake': [123.06, 122.20],
    'Lassen': [121.20, 119.59],
    'Los Angeles': [118.57, 117.38],
    'Madera': [120.33, 119.01],
    'Marin': [123.02, 122.25],
    'Mariposa': [120.24, 119.18],
    'Mendocino': [124.02, 122.49],
    'Merced': [121.15, 120.03],
    'Modoc': [121.28, 119.59],
    'Mono': [119.39, 117.49],
    'Monterey': [121.59, 120.12],
    'Napa': [122.39, 122.03],
    'Nevada': [121.17, 120.00],
    'Orange': [118.08, 117.24],
    'Placer': [121.29, 120.00],
    'Plumas': [121.30, 120.05],
    'Riverside': [117.41, 114.26],
    'Sacramento': [121.52, 121.01],
    'San Benito': [121.39, 120.35],
    'San Bernardino': [117.49, 114.07],
    'San Diego': [117.36, 116.04],
    'San Francisco': [122.31, 122.21],
    'San Joaquin': [121.35, 120.56],
    'San Luis Obispo': [121.21, 119.27],
    'San Mateo': [122.32, 122.04],
    'Santa Barbara': [120.39, 119.26],
    'Santa Clara': [122.13, 121.12],
    'Santa Cruz': [122.19, 121.35],
    'Shasta': [123.05, 121.19],
    'Sierra': [121.04, 120.00],
    'Siskiyou': [123.43, 121.26],
    'Solano': [122.25, 121.35],
    'Sonoma': [123.33, 122.20],
    'Stanislaus': [121.30, 120.23],
    'Sutter': [121.57, 121.24],
    'Tehama': [123.04, 121.18],
    'Trinity': [123.38, 122.26],
    'Tulare': [119.35, 118.58],
    'Tuolumne': [120.40, 119.11],
    'Ventura': [119.29, 118.37],
    'Yolo': [122.26, 121.30],
    'Yuba': [121.39, 121.00]
}

# California county coordinates
county_latitude_ranges = {
    'Alameda': [37.55, 37.27],
    'Alpine': [38.56, 38.20],
    'Amador': [38.43, 38.13],
    'Butte': [40.10, 39.17],
    'Calaveras': [38.31, 37.49],
    'Colusa': [39.25, 38.55],
    'Contra Costa': [38.07, 37.43],
    'Del Norte': [42.00, 41.22],
    'El Dorado': [39.05, 38.30],
    'Fresno': [37.36, 35.54],
    'Glenn': [39.48, 39.23],
    'Humboldt': [41.29, 40.00],
    'Imperial': [33.26, 32.36],
    'Inyo': [37.28, 35.47],
    'Kern': [35.48, 34.48],
    'Kings': [36.30, 35.47],
    'Lake': [39.35, 38.39],
    'Lassen': [41.12, 39.42],
    'Los Angeles': [34.50, 33.42],
    'Madera': [37.47, 36.45],
    'Marin': [38.20, 37.48],
    'Mariposa': [38.54, 37.11],
    'Mendocino': [40.01, 38.45],
    'Merced': [37.38, 36.44],
    'Modoc': [42.00, 41.11],
    'Mono': [38.43, 37.27],
    'Monterey': [36.56, 35.47],
    'Napa': [38.52, 38.09],
    'Nevada': [39.32, 39.00],
    'Orange': [33.57, 33.23],
    'Placer': [39.19, 38.42],
    'Plumas': [40.27, 39.35],
    'Riverside': [34.05, 33.25],
    'Sacramento': [38.44, 38.01],
    'San Benito': [37.00, 36.11],
    'San Bernardino': [35.49, 33.52],
    'San Diego': [33.31, 32.32],
    'San Francisco': [37.49, 37.42],
    'San Joaquin': [38.18, 37.29],
    'San Luis Obispo': [35.48, 34.56],
    'San Mateo': [37.42, 37.06],
    'Santa Barbara': [35.07, 34.22],
    'Santa Clara': [37.29, 36.53],
    'Santa Cruz': [37.17, 36.51],
    'Shasta': [41.12, 40.17],
    'Sierra': [39.47, 39.23],
    'Siskiyou': [42.01, 40.59],
    'Solano': [38.33, 38.02],
    'Sonoma': [38.52, 38.04],
    'Stanislaus': [38.05, 37.11],
    'Sutter': [39.19, 38.43],
    'Tehama': [40.27, 39.47],
    'Trinity': [41.22, 39.58],
    'Tulare': [36.45, 35.47],
    'Tuolumne': [38.26, 37.38],
    'Ventura': [34.54, 34.02],
    'Yolo': [38.56, 38.19],
    'Yuba': [39.39, 38.55]
}

county_longitudes = {county : np.mean(county_longitude_ranges[county]) for county in county_longitude_ranges}
county_latitudes = {county : np.mean(county_latitude_ranges[county]) for county in county_latitude_ranges}

# %%
import matplotlib.pyplot as plt

for county in counties:
    xi = 180 - county_longitudes[county]
    yi = county_latitudes[county]
    plt.scatter(xi, yi, c="lightsteelblue", edgecolors='cornflowerblue', alpha=0.7)
    plt.xlabel('180 - longitude')
    plt.ylabel('latitude')
    plt.title('California Counties\' Connectivity1')

for i in range(58):
    for j in range(58):
        if C[i][j] == 0 or i > j:
            continue
        x1 = 180 - county_longitudes[counties[i]]
        y1 = county_latitudes[counties[i]]
        x2 = 180 - county_longitudes[counties[j]]
        y2 = county_latitudes[counties[j]]
        x = np.array((x1, x2))
        y = np.array((y1, y2))
        
        if C[i][j] >= 0.75:
            plt.plot(x, y, c='maroon', linewidth=2)
        elif C[i][j] >= 0.5:
            plt.plot(x, y, c='tomato', linewidth=2)
        elif C[i][j] >= 0.25:
            plt.plot(x, y, c='salmon', linewidth=2)
        else:
            plt.plot(x, y, c='mistyrose', linewidth=2)

plt.show()

# %%
for county in counties:
    xi = 180 - county_longitudes[county]
    yi = county_latitudes[county]
    plt.scatter(xi, yi, c="lightsteelblue", edgecolors='cornflowerblue', alpha=0.7)
    plt.xlabel('180 - longitude')
    plt.ylabel('latitude')
    plt.title('California Counties\' Connectivity2')

for i in range(58):
    for j in range(58):
        if C[i][j] == 0 or i <= j:
            continue
        x1 = 180 - county_longitudes[counties[i]]
        y1 = county_latitudes[counties[i]]
        x2 = 180 - county_longitudes[counties[j]]
        y2 = county_latitudes[counties[j]]
        x = np.array((x1, x2))
        y = np.array((y1, y2))

        if C[i][j] >= 0.75:
            plt.plot(x, y, c='darkgreen', linewidth=2)
        elif C[i][j] >= 0.5:
            plt.plot(x, y, c='seagreen', linewidth=2)
        elif C[i][j] >= 0.25:
            plt.plot(x, y, c='mediumseagreen', linewidth=2)
        else:
            plt.plot(x, y, c='springgreen', linewidth=2)

plt.show()
